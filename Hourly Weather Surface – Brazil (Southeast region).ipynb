# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\granv\Downloads\archive\central_west.csv')

df
# Out:
#            index        Data   Hora  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0         138998  2017-12-20  14:00                               0.0
# 1         138999  2017-12-20  15:00                               0.0
# 2         139000  2017-12-20  16:00                               0.0
# 3         139001  2017-12-20  17:00                               0.0
# 4         139002  2017-12-20  18:00                               0.0
# ...          ...         ...    ...                               ...
# 11427115  138993  2017-12-20  09:00                               0.0
# 11427116  138994  2017-12-20  10:00                               0.0
# 11427117  138995  2017-12-20  11:00                               0.0
# 11427118  138996  2017-12-20  12:00                               0.0
# 11427119  138997  2017-12-20  13:00                               0.0
#
#           PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                     899.6
# ...

# %%
#Check the dataframe

df.head(1)
# Out:
#     index        Data   Hora  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0  138998  2017-12-20  14:00                               0.0
#
#    PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              899.6
#
#    PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                            900.0
#
#    PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  RADIACAO GLOBAL (Kj/m²)  \
# 0                                             899.6                     3391
#
#    TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)  \
# 0                                          26.5
#
#    TEMPERATURA DO PONTO DE ORVALHO (°C)  ...  \
# 0                                  17.7  ...
#
#    VENTO, DIREÇÃO HORARIA (gr) (° (gr))  VENTO, RAJADA MAXIMA (m/s)  \
# 0                                    39                         9.6
#
#    VENTO, VELOCIDADE HORARIA (m/s)  region  state             station  \
# ...

# %%
#Check columns list

print (df.columns)
# Out:
# Index(['index', 'Data', 'Hora', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)',
#        'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)',
#        'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
#        'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)',
#        'RADIACAO GLOBAL (Kj/m²)',
#        'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)',
#        'TEMPERATURA DO PONTO DE ORVALHO (°C)',
#        'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)',
#        'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)',
#        'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)',
#        'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)',
#        'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)',
#        'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)',
#        'UMIDADE RELATIVA DO AR, HORARIA (%)',
#        'VENTO, DIREÇÃO HORARIA (gr) (° (gr))', 'VENTO, RAJADA MAXIMA (m/s)',
#        'VENTO, VELOCIDADE HORARIA (m/s)', 'region', 'state', 'station',
#        'station_code', 'latitude', 'longitude', 'height'],
# ...

# %%
#Rename columns

df.rename(columns={'index': 'Index', 'Data': 'Date', 'Hora': 'Hour', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)':'Total Rainfall, Time (mm)', 'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)':'Atmospheric Pressure at Season Level, Hourly(mB)', 'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)': 'Max Atmospheric Pressure in the Previous Hour. (AUT)(mB)', 'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)': 'Atmospheric Pressure Min. in the Earliest Hour. (AUT)(mB)', 'RADIACAO GLOBAL (Kj/m²)': 'Global Radiation (Kj/m²)', 'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)': 'Air Temperature - Dry Bulb, Hours (°C)', 'TEMPERATURA DO PONTO DE ORVALHO (°C)': 'Dew Point Temperature (°C)','TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)': 'Maximum Temperature in the Previous Hour (AUT)(°C)','TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)': 'Minimum Temperature in the Previous Hour (AUT)(°C)','TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)': 'Dew Temperature Max in the Earliest Hour (AUT) (°C)', 'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)': 'Dew Temperature Min in the Earliest Hour (AUT) (°C)','TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)': 'Minimum Temperature in the Previous Hour(AUT) (°C)', 'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)': 'Humidity Rel. Max in the Earliest Hour (AUT)(%)', 'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)': 'Humidity Rel. Min in the Earliest Hour (AUT)(%)', 'UMIDADE RELATIVA DO AR, HORARIA (%)': 'Relative Air Humidity, Hourly (%)', 'VENTO, DIREÇÃO HORARIA (gr) (° (gr))': 'Wind, Clockwise Direction (gr) (° (gr))', 'VENTO, RAJADA MAXIMA (m/s)': 'Wind, Maximum Gust (m/s)', 'VENTO, VELOCIDADE HORARIA (m/s)': 'Wind, Hourly Speed (m/s)', 'region': 'Region', 'state': 'State', 'station': 'Station', 'station_code': 'Station Code', 'latitude': 'Latitude', 'longitude': 'Longitude', 'height': 'Height'}, inplace=True)

# %%
df.head()
# Out:
#     Index        Date   Hour  Total Rainfall, Time (mm)  \
# 0  138998  2017-12-20  14:00                        0.0
# 1  138999  2017-12-20  15:00                        0.0
# 2  139000  2017-12-20  16:00                        0.0
# 3  139001  2017-12-20  17:00                        0.0
# 4  139002  2017-12-20  18:00                        0.0
#
#    Atmospheric Pressure at Season Level, Hourly(mB)  \
# 0                                             899.6
# 1                                             899.2
# 2                                             898.6
# 3                                             897.7
# 4                                             897.0
#
#    Max Atmospheric Pressure in the Previous Hour. (AUT)(mB)  \
# 0                                              900.0
# 1                                              899.6
# 2                                              899.2
# 3                                              898.6
# ...

# %%
#Check if columns are renamed

df.columns
# Out:
# Index(['Index', 'Date', 'Hour', 'Total Rainfall, Time (mm)',
#        'Atmospheric Pressure at Season Level, Hourly(mB)',
#        'Max Atmospheric Pressure in the Previous Hour. (AUT)(mB)',
#        'Atmospheric Pressure Min. in the Earliest Hour. (AUT)(mB)',
#        'Global Radiation (Kj/m²)', 'Air Temperature - Dry Bulb, Hours (°C)',
#        'Dew Point Temperature (°C)',
#        'Maximum Temperature in the Previous Hour (AUT)(°C)',
#        'Minimum Temperature in the Previous Hour(AUT) (°C)',
#        'Dew Temperature Max in the Earliest Hour (AUT) (°C)',
#        'Dew Temperature Min in the Earliest Hour (AUT) (°C)',
#        'Humidity Rel. Max in the Earliest Hour (AUT)(%)',
#        'Humidity Rel. Min in the Earliest Hour (AUT)(%)',
#        'Relative Air Humidity, Hourly (%)',
#        'Wind, Clockwise Direction (gr) (° (gr))', 'Wind, Maximum Gust (m/s)',
#        'Wind, Hourly Speed (m/s)', 'Region', 'State', 'Station',
# ...

# %%
#Drop columns that seem not useful

df = df.drop(columns=['Region', 'State', 'Station','Station Code', 'Latitude', 'Longitude', 'Height'])

df
# Out:
#            Index        Date   Hour  Total Rainfall, Time (mm)  \
# 0         138998  2017-12-20  14:00                        0.0
# 1         138999  2017-12-20  15:00                        0.0
# 2         139000  2017-12-20  16:00                        0.0
# 3         139001  2017-12-20  17:00                        0.0
# 4         139002  2017-12-20  18:00                        0.0
# ...          ...         ...    ...                        ...
# 11427115  138993  2017-12-20  09:00                        0.0
# 11427116  138994  2017-12-20  10:00                        0.0
# 11427117  138995  2017-12-20  11:00                        0.0
# 11427118  138996  2017-12-20  12:00                        0.0
# 11427119  138997  2017-12-20  13:00                        0.0
#
#           Atmospheric Pressure at Season Level, Hourly(mB)  \
# 0                                                    899.6
# 1                                                    899.2
# ...
